# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
PROJ_path = "/content/drive/MyDrive/Colab Notebooks/first_github"
# %cd "{PROJ_path}"
# %pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/first_github
# '/content/drive/MyDrive/Colab Notebooks/first_github'

# %%
with open("./README.md", "r") as f:
  c = f.read()
print(c)
# Out:
# # first_github

# %%
# !git config uesr.email "crickstein@gmail.com"
# !git config user.name "crickstein"
# !git status

# %%
# !git add prac1.ipynb
# !git commit -m "prac1 inital commit"
# !git push origin main
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@448c04c7096b.(none)')
# Everything up-to-date
